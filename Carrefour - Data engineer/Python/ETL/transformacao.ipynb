# %%
import pandas as pd
import pandera as pa

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%d/%m/%Y')

valores_ausentes = ['##!', '####', '****', '*****', '**', 'NULL']

df = pd.read_csv('ocorrencia_2010_2020.csv', sep=',', parse_dates=['ocorrencia_dia'], date_parser=dateparse, na_values=valores_ausentes)
df.head(10)
# Out:
# /home/michell/Documentos/Projetos/Dio/ETL com Python/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                  NaN     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                  NaN     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                  NaN     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %%
schema = pa.DataFrameSchema(
    columns = {
        'codigo': pa.Column(pa.Int, required=False),
        'codigo_ocorrencia': pa.Column(pa.Int),
        'codigo_ocorrencia2': pa.Column(pa.Int),
        'ocorrencia_classificacao': pa.Column(pa.String),
        'ocorrencia_cidade': pa.Column(pa.String),
        'ocorrencia_uf': pa.Column(pa.String, pa.Check.str_length(2, 2), nullable=True),
        'ocorrencia_aerodromo': pa.Column(pa.String, nullable=True),
        'ocorrencia_dia': pa.Column(pa.DateTime),
        'ocorrencia_hora': pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'), nullable=True),
        'total_recomendacoes': pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
# 5740              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 5736            CAMPINAS            SP                 SBKP     2020-12-29
# 5737   LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5738      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5739           VICENTINA            MS                  NaN     2020-12-31
# 5740           VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 5736        19:00:00                    0
# 5737        18:30:00                    0
# 5738        00:54:00                    0
# 5739        09:00:00                    0
# 5740        09:00:00                    0
#
# [5741 rows x 9 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# codigo_ocorrencia                         79756
# codigo_ocorrencia2                        79756
# ocorrencia_classificacao        INCIDENTE GRAVE
# ocorrencia_cidade                     VICENTINA
# ocorrencia_uf                                MS
# ocorrencia_aerodromo                        NaN
# ocorrencia_dia              2020-12-31 00:00:00
# ocorrencia_hora                        09:00:00
# total_recomendacoes                           0
# Name: 5740, dtype: object

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
# 5740              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5736           CAMPINAS            SP                 SBKP     2020-12-29
# 5737  LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5738     RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5739          VICENTINA            MS                  NaN     2020-12-31
# 5740          VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5736        19:00:00                    0
# 5737        18:30:00                    0
# 5738        00:54:00                    0
# 5739        09:00:00                    0
# 5740        09:00:00                    0

# %% [markdown]
# Procura item pelo índice

# %%
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# 12        03:00:00                    0
# 13        17:00:00                    2
# 14        14:30:00                    0

# %% [markdown]
# Procura item pelo label

# %%
df.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
# 15            CANUTAMA            AM                  NaN     2010-01-15
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# 12        03:00:00                    0
# 13        17:00:00                    2
# 14        14:30:00                    0
# 15        21:22:00                    0

# %%
df.loc[:,'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5736    SP
# 5737    TO
# 5738    RJ
# 5739    MS
# 5740    MS
# Name: ocorrencia_uf, Length: 5741, dtype: object

# %%
df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5736    SP
# 5737    TO
# 5738    RJ
# 5739    MS
# 5740    MS
# Name: ocorrencia_uf, Length: 5741, dtype: object

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2339
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2339
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
filtro = df.ocorrencia_uf.isnull()

df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0

# %%
filtro = df.ocorrencia_aerodromo.isnull()

df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5733              79753               79753          INCIDENTE GRAVE
# 5734              79755               79755                 ACIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5739              79756               79756          INCIDENTE GRAVE
# 5740              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 5               SALVADOR            BA                  NaN     2010-01-06
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 9          PARÁ DE MINAS            MG                  NaN     2010-01-10
# ...                  ...           ...                  ...            ...
# 5733            GOIATUBA            GO                  NaN     2020-12-29
# 5734           MATO RICO            PR                  NaN     2020-12-29
# 5737   LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5739           VICENTINA            MS                  NaN     2020-12-31
# 5740           VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 3           17:30:00                    0
# 5           17:53:00                    0
# 7           12:30:00                    3
# 9           20:00:00                    0
# ...              ...                  ...
# 5733        12:00:00                    0
# 5734        10:30:00                    0
# 5737        18:30:00                    0
# 5739        09:00:00                    0
# 5740        09:00:00                    0
#
# [2339 rows x 9 columns]

# %%
filtro = df.ocorrencia_hora.isnull()

df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4098              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4098           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4098             NaN                    0

# %% [markdown]
# Contagem de valores - Função count por padrão não conta valores não informados.

# %%
df.count()
# Out:
# codigo_ocorrencia           5741
# codigo_ocorrencia2          5741
# ocorrencia_classificacao    5741
# ocorrencia_cidade           5741
# ocorrencia_uf               5740
# ocorrencia_aerodromo        3402
# ocorrencia_dia              5741
# ocorrencia_hora             5740
# total_recomendacoes         5741
# dtype: int64

# %% [markdown]
# Ocorrências com mais de 10 recomendações

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2795              52265               52265                 ACIDENTE
# 3928              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# 326         RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
# 530              SÃO PAULO            SP                  NaN     2010-12-14
# 727               ITÁPOLIS            SP                 SDIO     2011-04-09
# 872                 RECIFE            PE                 SBRF     2011-07-13
# 884   SÃO JOSÉ DOS PINHAIS            PR                 SBCT     2011-07-15
# 1062            UBERLÂNDIA            MG                 SBUL     2011-11-15
# 1972              BRASÍLIA            DF                 SBBR     2013-04-13
# 2795                SANTOS            SP                  NaN     2014-08-13
# 3928               VITÓRIA            ES                  NaN     2017-02-21
#
#      ocorrencia_hora  total_recomendacoes
# 63          20:07:00                   11
# 326         12:26:00                   19
# 530         20:15:00                   11
# 727         14:50:00                   11
# 872         09:54:00                   23
# 884         17:05:00                   11
# 1062        02:15:00                   20
# 1972        18:00:00                   11
# 2795        13:03:00                   13
# 3928        11:47:00                   12

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2795                SANTOS                   13
# 3928               VITÓRIA                   12

# %%
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5733              79753               79753          INCIDENTE GRAVE
# 5735              79769               79769          INCIDENTE GRAVE
# 5737              79757               79757          INCIDENTE GRAVE
# 5739              79756               79756          INCIDENTE GRAVE
# 5740              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7              CANUTAMA            AM                  NaN     2010-01-09
# 8              CASCAVEL            PR                 SBCA     2010-01-10
# 9         PARÁ DE MINAS            MG                  NaN     2010-01-10
# 29             CURITIBA            PR                 SBBI     2010-01-23
# 35               PALMAS            TO                 SBPJ     2010-01-26
# ...                 ...           ...                  ...            ...
# 5733           GOIATUBA            GO                  NaN     2020-12-29
# 5735      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5737  LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5739          VICENTINA            MS                  NaN     2020-12-31
# 5740          VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 29          16:36:00                    2
# 35          16:50:00                    0
# ...              ...                  ...
# 5733        12:00:00                    0
# 5735        18:30:00                    0
# 5737        18:30:00                    0
# 5739        09:00:00                    0
# 5740        09:00:00                    0
#
# [733 rows x 9 columns]

# %% [markdown]
# Combinando filtros - Usando E (&)

# %%
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5583              79540               79540          INCIDENTE GRAVE
# 5602              79566               79566          INCIDENTE GRAVE
# 5694              79739               79739          INCIDENTE GRAVE
# 5695              79705               79705          INCIDENTE GRAVE
# 5705              79718               79718          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 136            PIRASSUNUNGA            SP                 SDPY     2010-04-15
# 171               GUARULHOS            SP                 SBGR     2010-05-06
# 219               SÃO PAULO            SP                 SBMT     2010-06-08
# 297               SÃO PAULO            SP                 SBMT     2010-07-29
# 314   SÃO JOSÉ DO RIO PRETO            SP                 SBSR     2010-08-05
# ...                     ...           ...                  ...            ...
# 5583              SÃO PAULO            SP                  NaN     2020-09-12
# 5602          REGENTE FEIJÓ            SP                 SDYJ     2020-09-27
# 5694              SÃO PAULO            SP                 SBSP     2020-12-03
# 5695               SOROCABA            SP                 SDCO     2020-12-04
# 5705              SÃO PAULO            SP                 SBMT     2020-12-11
#
#      ocorrencia_hora  total_recomendacoes
# 136         20:15:00                    0
# 171         15:50:00                    0
# 219         19:30:00                    2
# 297         20:06:00                    0
# 314         12:01:00                    0
# ...              ...                  ...
# 5583        13:10:00                    0
# 5602        19:33:00                    0
# 5694        14:42:00                    0
# 5695        15:30:00                    0
# 5705        13:50:00                    0
#
# [136 rows x 9 columns]

# %% [markdown]
# Combinando filtros - Usando OU (|)

# %%
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5739              79756               79756          INCIDENTE GRAVE
# 5740              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7              CANUTAMA            AM                  NaN     2010-01-09
# 8              CASCAVEL            PR                 SBCA     2010-01-10
# 9         PARÁ DE MINAS            MG                  NaN     2010-01-10
# 11            SÃO PAULO            SP                 SBMT     2010-01-10
# 16            SÃO PAULO            SP                  NaN     2010-01-15
# ...                 ...           ...                  ...            ...
# 5735      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5736           CAMPINAS            SP                 SBKP     2020-12-29
# 5737  LAGOA DA CONFUSÃO            TO                  NaN     2020-12-30
# 5739          VICENTINA            MS                  NaN     2020-12-31
# 5740          VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 11          14:50:00                    8
# 16          15:00:00                    0
# ...              ...                  ...
# 5735        18:30:00                    0
# 5736        19:00:00                    0
# 5737        18:30:00                    0
# 5739        09:00:00                    0
# 5740        09:00:00                    0
#
# [1968 rows x 9 columns]

# %%
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5694              79739               79739          INCIDENTE GRAVE
# 5695              79705               79705          INCIDENTE GRAVE
# 5705              79718               79718          INCIDENTE GRAVE
# 5731              79800               79800                INCIDENTE
# 5736              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 16           SÃO PAULO            SP                  NaN     2010-01-15
# 18              SANTOS            SP                  NaN     2010-01-15
# 26            SOROCABA            SP                  NaN     2010-01-20
# 27            CAMPINAS            SP                  NaN     2010-01-21
# 33           GUARULHOS            SP                 SBGR     2010-01-25
# ...                ...           ...                  ...            ...
# 5694         SÃO PAULO            SP                 SBSP     2020-12-03
# 5695          SOROCABA            SP                 SDCO     2020-12-04
# 5705         SÃO PAULO            SP                 SBMT     2020-12-11
# 5731         SÃO PAULO            SP                 SBMT     2020-12-28
# 5736          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 16          15:00:00                    0
# 18          17:45:00                    0
# 26          13:10:00                    0
# 27          20:45:00                    0
# 33          17:05:00                    0
# ...              ...                  ...
# 5694        14:42:00                    0
# 5695        15:30:00                    0
# 5705        13:50:00                    0
# 5731        10:15:00                    0
# 5736        19:00:00                    0
#
# [984 rows x 9 columns]

# %% [markdown]
# Analisar parte do valor na coluna

# %%
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 5652              79649               79649                INCIDENTE
# 5654              79652               79652                INCIDENTE
# 5670              79683               79683                INCIDENTE
# 5686              79692               79692                 ACIDENTE
# 5736              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                COARI            AM                 SBUY     2010-01-07
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 8             CASCAVEL            PR                 SBCA     2010-01-10
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 20     CRUZEIRO DO SUL            AC                 SBCZ     2010-01-18
# ...                ...           ...                  ...            ...
# 5652          CAMPINAS            SP                 SBKP     2020-11-04
# 5654           CONFINS            MG                 SBCF     2020-11-06
# 5670   CRUZEIRO DO SUL            AC                 SBCZ     2020-11-16
# 5686         CATANDUVA            SP                 SDCD     2020-11-28
# 5736          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:40:00                    0
# 7           12:30:00                    3
# 8           23:15:00                    2
# 15          21:22:00                    0
# 20          19:32:00                    0
# ...              ...                  ...
# 5652        22:39:00                    0
# 5654        14:20:00                    0
# 5670        22:00:00                    0
# 5686        12:50:00                    0
# 5736        19:00:00                    0
#
# [825 rows x 9 columns]

# %%
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 5728              79749               79749                 ACIDENTE
# 5732              79824               79824                 ACIDENTE
# 5733              79753               79753          INCIDENTE GRAVE
# 5739              79756               79756          INCIDENTE GRAVE
# 5740              79756               79756          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 25          UBERLÂNDIA            MG                  NaN     2010-01-20
# 26            SOROCABA            SP                  NaN     2010-01-20
# ...                ...           ...                  ...            ...
# 5728          MARITUBA            PA                  NaN     2020-12-26
# 5732     RIO PARANAÍBA            MG                 SNRP     2020-12-28
# 5733          GOIATUBA            GO                  NaN     2020-12-29
# 5739         VICENTINA            MS                  NaN     2020-12-31
# 5740         VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 12          03:00:00                    0
# 15          21:22:00                    0
# 25          18:58:00                    0
# 26          13:10:00                    0
# ...              ...                  ...
# 5728        12:05:00                    0
# 5732        17:00:00                    0
# 5733        12:00:00                    0
# 5739        09:00:00                    0
# 5740        09:00:00                    0
#
# [1553 rows x 9 columns]

# %%
filtro = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 408               43062               43062                 ACIDENTE
# 688               44198               44198                 ACIDENTE
# 1035              51785               51785                INCIDENTE
# 1377              45939               45939                 ACIDENTE
# 1401              46180               46180                 ACIDENTE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799                 ACIDENTE
# 2655              51347               51347                INCIDENTE
# 2855              52340               52340                 ACIDENTE
# 2965              52832               52832                 ACIDENTE
# 2995              52979               52979                 ACIDENTE
# 3038              52984               52984                 ACIDENTE
# 3090              53596               53596                INCIDENTE
# 3155              53223               53223                 ACIDENTE
# 3169              53265               53265                 ACIDENTE
# 3187              53271               53271          INCIDENTE GRAVE
# 3680              65414               65414          INCIDENTE GRAVE
# 3723              65633               65633          INCIDENTE GRAVE
# 3879              66265               66265                 ACIDENTE
# 4227              77371               77371                 ACIDENTE
# 4309              77612               77612                 ACIDENTE
# 4570              78080               78080                 ACIDENTE
# 4981              78867               78867                INCIDENTE
# 5065              78923               78923          INCIDENTE GRAVE
# 5075              78782               78782                 ACIDENTE
# 5400              79282               79282                 ACIDENTE
# 5435              79338               79338                INCIDENTE
# 5468              79400               79400                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 408          NOVO GAMA            GO                  NaN     2010-09-25
# 688           BURITAMA            SP                  NaN     2011-03-19
# 1035          BURITAMA            SP                 SIBX     2011-10-25
# 1377          UMUARAMA            PR                  NaN     2012-05-30
# 1401         AURIFLAMA            SP                  NaN     2012-06-16
# 2099         NOVA LIMA            MG                  NaN     2013-06-15
# 2102          CANUTAMA            AM                  NaN     2013-06-18
# 2655           DIADEMA            SP                  NaN     2014-05-04
# 2855              FAMA            MG                  NaN     2014-09-20
# 2965          BURITAMA            SP                  NaN     2014-12-14
# 2995          IVINHEMA            MS                  NaN     2015-01-02
# 3038         NOVA LIMA            MG                 SJLY     2015-02-01
# 3090           ITAPEMA            SC                  NaN     2015-03-10
# 3155         PINDORAMA            SP                  NaN     2015-04-22
# 3169         PACARAIMA            RR                 SDMM     2015-05-05
# 3187          UMUARAMA            PR                  NaN     2015-05-17
# 3680         NOVA LIMA            MG                 SJLY     2016-07-08
# 3723         NOVA LIMA            MG                  NaN     2016-08-31
# 3879          BURITAMA            SP                  NaN     2017-01-13
# 4227          CANUTAMA            AM                 SDKH     2017-11-02
# 4309           ITAPEMA            SC                  NaN     2018-01-06
# 4570           ITAPEMA            SC                  NaN     2018-07-28
# 4981           IRACEMA            RR                  NaN     2019-07-06
# 5065          CANUTAMA            AM                  NaN     2019-09-03
# 5075          IVINHEMA            MS                  NaN     2019-09-08
# 5400           ITURAMA            MG                  NaN     2020-04-11
# 5435          IVINHEMA            MS                  NaN     2020-05-15
# 5468           IBIRAMA            SC                  NaN     2020-06-09
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 15          21:22:00                    0
# 408         16:30:00                    1
# 688         11:18:00                    0
# 1035        19:15:00                    0
# 1377        19:00:00                    0
# 1401        19:30:00                    0
# 2099        12:00:00                    4
# 2102        21:30:00                    0
# 2655        16:00:00                    0
# 2855        15:00:00                    1
# 2965        23:40:00                    0
# 2995        14:50:00                    0
# 3038        15:10:00                    0
# 3090        21:35:00                    0
# 3155        12:45:00                    0
# 3169        16:05:00                    2
# 3187        17:00:00                    0
# 3680        19:50:00                    1
# 3723        17:40:00                    0
# 3879        16:00:00                    0
# 4227        19:30:00                    1
# 4309        10:30:00                    0
# 4570        14:20:00                    0
# 4981        00:00:00                    0
# 5065        14:00:00                    0
# 5075        17:45:00                    0
# 5400        12:20:00                    0
# 5435        09:40:00                    0
# 5468        14:00:00                    0

# %%
filtro = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 35                39487               39487          INCIDENTE GRAVE
# 78                39916               39916          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5722              79745               79745                INCIDENTE
# 5728              79749               79749                 ACIDENTE
# 5730              79754               79754          INCIDENTE GRAVE
# 5734              79755               79755                 ACIDENTE
# 5735              79769               79769          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 13    PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 15              CANUTAMA            AM                  NaN     2010-01-15
# 35                PALMAS            TO                 SBPJ     2010-01-26
# 78                MANAUS            AM                 SBEG     2010-03-07
# ...                  ...           ...                  ...            ...
# 5722              MARABÁ            PA                 SBMA     2020-12-21
# 5728            MARITUBA            PA                  NaN     2020-12-26
# 5730        NOVA MARINGÁ            MT                  NaN     2020-12-28
# 5734           MATO RICO            PR                  NaN     2020-12-29
# 5735       MANOEL URBANO            AC                 SIMB     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 13          17:00:00                    2
# 15          21:22:00                    0
# 35          16:50:00                    0
# 78          19:35:00                    2
# ...              ...                  ...
# 5722        08:47:00                    0
# 5728        12:05:00                    0
# 5730        13:00:00                    0
# 5734        10:30:00                    0
# 5735        18:30:00                    0
#
# [488 rows x 9 columns]

# %%
filtro = df.ocorrencia_cidade.str.contains('MA|AL')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 17                39810               39810                INCIDENTE
# ...                 ...                 ...                      ...
# 5727              79787               79787                INCIDENTE
# 5728              79749               79749                 ACIDENTE
# 5730              79754               79754          INCIDENTE GRAVE
# 5734              79755               79755                 ACIDENTE
# 5735              79769               79769          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5               SALVADOR            BA                  NaN     2010-01-06
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 13    PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 15              CANUTAMA            AM                  NaN     2010-01-15
# 17              SALVADOR            BA                  NaN     2010-01-15
# ...                  ...           ...                  ...            ...
# 5727           FORTALEZA            CE                 SBFZ     2020-12-23
# 5728            MARITUBA            PA                  NaN     2020-12-26
# 5730        NOVA MARINGÁ            MT                  NaN     2020-12-28
# 5734           MATO RICO            PR                  NaN     2020-12-29
# 5735       MANOEL URBANO            AC                 SIMB     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 5           17:53:00                    0
# 7           12:30:00                    3
# 13          17:00:00                    2
# 15          21:22:00                    0
# 17          18:23:00                    0
# ...              ...                  ...
# 5727        18:30:00                    0
# 5728        12:05:00                    0
# 5730        13:00:00                    0
# 5734        10:30:00                    0
# 5735        18:30:00                    0
#
# [902 rows x 9 columns]

# %%
filtro = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2994              52992               52992          INCIDENTE GRAVE
# 2995              52979               52979                 ACIDENTE
# 2996              53073               53073                INCIDENTE
# 2997              53074               53074                INCIDENTE
# 2998              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3460              60632               60632          INCIDENTE GRAVE
# 3461              60600               60600                INCIDENTE
# 3462              60642               60642                INCIDENTE
# 3463              60631               60631                 ACIDENTE
# 3464              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2994              SALVADOR            BA                 SBSV     2015-01-01
# 2995              IVINHEMA            MS                  NaN     2015-01-02
# 2996                  TEFÉ            AM                 SBTF     2015-01-02
# 2997        BELO HORIZONTE            MG                 SBBH     2015-01-02
# 2998                TOLEDO            PR                 SBTD     2015-01-04
# ...                    ...           ...                  ...            ...
# 3460               ITABERÁ            SP                  NaN     2015-12-24
# 3461             GUARULHOS            SP                 SBGR     2015-12-25
# 3462  SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 3463             MAÇAMBARÁ            RS                  NaN     2015-12-28
# 3464            PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 2994        11:40:00                    3
# 2995        14:50:00                    0
# 2996        16:28:00                    0
# 2997        20:34:00                    0
# 2998        22:04:00                    6
# ...              ...                  ...
# 3460        14:00:00                    0
# 3461        19:00:00                    0
# 3462        16:00:00                    0
# 3463        19:00:00                    2
# 3464        14:00:00                    0
#
# [471 rows x 9 columns]

# %%
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12

df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3426              53573               53573                INCIDENTE
# 3427              60601               60601                INCIDENTE
# 3428              53634               53634                INCIDENTE
# 3429              53636               53636                INCIDENTE
# 3430              53575               53575                INCIDENTE
# 3431              60637               60637                INCIDENTE
# 3432              53625               53625                 ACIDENTE
# 3433              53626               53626                 ACIDENTE
# 3434              53628               53628                 ACIDENTE
# 3435              53629               53629                 ACIDENTE
# 3436              53631               53631                INCIDENTE
# 3437              60636               60636                INCIDENTE
# 3438              53627               53627                INCIDENTE
# 3439              60604               60604                INCIDENTE
# 3440              60611               60611                INCIDENTE
# 3441              60613               60613                 ACIDENTE
# 3442              60629               60629                 ACIDENTE
# 3443              53630               53630                INCIDENTE
# 3444              60603               60603                INCIDENTE
# 3445              60612               60612                 ACIDENTE
# 3446              60783               60783                 ACIDENTE
# 3447              53639               53639                INCIDENTE
# 3448              60609               60609          INCIDENTE GRAVE
# 3449              60616               60616                 ACIDENTE
# 3450              60620               60620                 ACIDENTE
# 3451              60645               60645                 ACIDENTE
# 3452              60608               60608                INCIDENTE
# 3453              60625               60625                 ACIDENTE
# 3454              60605               60605                INCIDENTE
# 3455              60610               60610                INCIDENTE
# 3456              60602               60602                INCIDENTE
# 3457              60615               60615                INCIDENTE
# 3458              60640               60640                INCIDENTE
# 3459              60641               60641                INCIDENTE
# 3460              60632               60632          INCIDENTE GRAVE
# 3461              60600               60600                INCIDENTE
# 3462              60642               60642                INCIDENTE
# 3463              60631               60631                 ACIDENTE
# 3464              60649               60649                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3426              GUARULHOS            SP                 SBGR     2015-12-01
# 3427                 PALMAS            TO                 SBPJ     2015-12-01
# 3428                 PALMAS            TO                 SBPJ     2015-12-02
# 3429                JUNDIAÍ            SP                 SBJD     2015-12-02
# 3430  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3431         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3432               TRINDADE            GO                  NaN     2015-12-06
# 3433              AMERICANA            SP                 SDAI     2015-12-06
# 3434                  AGUAÍ            SP                  NaN     2015-12-08
# 3435                  JALES            SP                 SDJL     2015-12-08
# 3436               CAMPINAS            SP                 SBKP     2015-12-08
# 3437          CAXIAS DO SUL            RS                 SBCX     2015-12-08
# 3438               TERESINA            PI                 SBTE     2015-12-12
# 3439                GOIÂNIA            GO                 SBGO     2015-12-12
# 3440              SÃO PAULO            SP                 SBSP     2015-12-12
# 3441             JUSCIMEIRA            MT                 SWMO     2015-12-12
# 3442             RIO GRANDE            RS                  NaN     2015-12-12
# 3443                MARÍLIA            SP                 SBML     2015-12-13
# 3444               LONDRINA            PR                 SBLO     2015-12-13
# 3445        BENTO GONÇALVES            RS                 SSBG     2015-12-13
# 3446                  LAGES            SC                  NaN     2015-12-13
# 3447               LOUVEIRA            SP                 SDAM     2015-12-15
# 3448              ARAGUAÍNA            TO                 SWGN     2015-12-15
# 3449               PALOTINA            PR                  NaN     2015-12-15
# 3450         RIO DE JANEIRO            RJ                 SBJR     2015-12-15
# 3451            SERTÃOZINHO            SP                  NaN     2015-12-15
# 3452         BELO HORIZONTE            MG                 SBPR     2015-12-16
# 3453               ITÁPOLIS            SP                 SDIO     2015-12-17
# 3454             UBERLÂNDIA            MG                 SBUL     2015-12-18
# 3455                JUNDIAÍ            SP                 SBJD     2015-12-18
# 3456         RIBEIRÃO PRETO            SP                 SBRP     2015-12-22
# 3457              SÃO PAULO            SP                 SBMT     2015-12-22
# 3458               CASCAVEL            PR                 SBCA     2015-12-23
# 3459         BELO HORIZONTE            MG                 SBBH     2015-12-23
# 3460                ITABERÁ            SP                  NaN     2015-12-24
# 3461              GUARULHOS            SP                 SBGR     2015-12-25
# 3462   SÃO FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 3463              MAÇAMBARÁ            RS                  NaN     2015-12-28
# 3464             PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 3426        02:48:00                    0
# 3427        16:05:00                    0
# 3428        17:45:00                    0
# 3429        17:42:00                    0
# 3430        10:50:00                    0
# 3431        16:47:00                    0
# 3432        13:10:00                    3
# 3433        15:00:00                    1
# 3434        14:30:00                    1
# 3435        10:20:00                    0
# 3436        16:19:00                    0
# 3437        13:00:00                    0
# 3438        19:05:00                    0
# 3439        14:34:00                    0
# 3440        15:30:00                    0
# 3441        08:31:00                    0
# 3442        10:40:00                    0
# 3443        13:50:00                    0
# 3444        17:46:00                    0
# 3445        20:30:00                    0
# 3446        14:00:00                    3
# 3447        14:20:00                    0
# 3448        13:00:00                    0
# 3449        20:30:00                    0
# 3450        16:50:00                    4
# 3451        13:00:00                    0
# 3452        10:38:00                    0
# 3453        21:30:00                    1
# 3454        10:25:00                    0
# 3455        18:45:00                    0
# 3456        06:27:00                    0
# 3457        13:07:00                    0
# 3458        13:20:00                    0
# 3459        15:53:00                    0
# 3460        14:00:00                    0
# 3461        19:00:00                    0
# 3462        16:00:00                    0
# 3463        19:00:00                    2
# 3464        14:00:00                    0

# %%
filtro_ano = df.ocorrencia_dia.dt.year == 2015
filtro_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia = df.ocorrencia_dia.dt.day == 15

df.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3447              53639               53639                INCIDENTE
# 3448              60609               60609          INCIDENTE GRAVE
# 3449              60616               60616                 ACIDENTE
# 3450              60620               60620                 ACIDENTE
# 3451              60645               60645                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3447          LOUVEIRA            SP                 SDAM     2015-12-15
# 3448         ARAGUAÍNA            TO                 SWGN     2015-12-15
# 3449          PALOTINA            PR                  NaN     2015-12-15
# 3450    RIO DE JANEIRO            RJ                 SBJR     2015-12-15
# 3451       SERTÃOZINHO            SP                  NaN     2015-12-15
#
#      ocorrencia_hora  total_recomendacoes
# 3447        14:20:00                    0
# 3448        13:00:00                    0
# 3449        20:30:00                    0
# 3450        16:50:00                    4
# 3451        13:00:00                    0

# %%
filtro_ano = df.ocorrencia_dia.dt.year == 2015
filtro_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia = (df.ocorrencia_dia.dt.day >= 3) & (df.ocorrencia_dia.dt.day <= 8)

df.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3430              53575               53575                INCIDENTE
# 3431              60637               60637                INCIDENTE
# 3432              53625               53625                 ACIDENTE
# 3433              53626               53626                 ACIDENTE
# 3434              53628               53628                 ACIDENTE
# 3435              53629               53629                 ACIDENTE
# 3436              53631               53631                INCIDENTE
# 3437              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3430  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3431         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3432               TRINDADE            GO                  NaN     2015-12-06
# 3433              AMERICANA            SP                 SDAI     2015-12-06
# 3434                  AGUAÍ            SP                  NaN     2015-12-08
# 3435                  JALES            SP                 SDJL     2015-12-08
# 3436               CAMPINAS            SP                 SBKP     2015-12-08
# 3437          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3430        10:50:00                    0
# 3431        16:47:00                    0
# 3432        13:10:00                    3
# 3433        15:00:00                    1
# 3434        14:30:00                    1
# 3435        10:20:00                    0
# 3436        16:19:00                    0
# 3437        13:00:00                    0

# %%
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                  NaN     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                  NaN     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                  NaN     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# 1        11:05:00                    0 2010-01-03 11:05:00
# 2        03:00:00                    0 2010-01-03 03:00:00
# 3        17:30:00                    0 2010-01-04 17:30:00
# 4        19:25:00                    0 2010-01-05 19:25:00
# 5        17:53:00                    0 2010-01-06 17:53:00
# 6        18:40:00                    0 2010-01-07 18:40:00
# 7        12:30:00                    3 2010-01-09 12:30:00
# 8        23:15:00                    2 2010-01-10 23:15:00
# 9        20:00:00                    0 2010-01-10 20:00:00

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
filtro_hora_inicio = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro_hora_final = df.ocorrencia_dia_hora <= '2015-12-08 13:00:00'

df.loc[filtro_hora_inicio & filtro_hora_final]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3431              60637               60637                INCIDENTE
# 3432              53625               53625                 ACIDENTE
# 3433              53626               53626                 ACIDENTE
# 3435              53629               53629                 ACIDENTE
# 3437              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3431    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3432          TRINDADE            GO                  NaN     2015-12-06
# 3433         AMERICANA            SP                 SDAI     2015-12-06
# 3435             JALES            SP                 SDJL     2015-12-08
# 3437     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 3431        16:47:00                    0 2015-12-03 16:47:00
# 3432        13:10:00                    3 2015-12-06 13:10:00
# 3433        15:00:00                    1 2015-12-06 15:00:00
# 3435        10:20:00                    0 2015-12-08 10:20:00
# 3437        13:00:00                    0 2015-12-08 13:00:00

# %% [markdown]
# Agrupamento de dados

# %%
filtro_ano = df.ocorrencia_dia.dt.year == 2015
filtro_mes = df.ocorrencia_dia.dt.month == 3
df201503 = df.loc[filtro_ano & filtro_mes]

# %%
df201503.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
filtro_ano = df.ocorrencia_dia.dt.year == 2010
filtro_local = df.ocorrencia_uf.isin(['SP', 'MG', 'ES', 'RJ'])
dfsudeste2010 = df.loc[filtro_ano & filtro_local]

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_uf', 'ocorrencia_classificacao']).size()
# Out:
# ocorrencia_uf  ocorrencia_classificacao
# ES             INCIDENTE                    5
# MG             ACIDENTE                     7
#                INCIDENTE                   39
#                INCIDENTE GRAVE              5
# RJ             ACIDENTE                     9
#                INCIDENTE                   52
#                INCIDENTE GRAVE              4
# SP             ACIDENTE                    24
#                INCIDENTE                   74
#                INCIDENTE GRAVE              9
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# SÃO PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACAÉ                    12
# CONFINS                   7
# UBERLÂNDIA                5
# VITÓRIA                   4
# JUIZ DE FORA              4
# SÃO JOSÉ DO RIO PRETO     3
# SÃO JOSÉ DOS CAMPOS       3
# MARÍLIA                   3
# ARARAQUARA                2
# MONTES CLAROS             2
# CAMPOS DOS GOYTACAZES     2
# DIVINÓPOLIS               2
# IPATINGA                  2
# ITANHAÉM                  2
# JUNDIAÍ                   2
# POÇOS DE CALDAS           2
# RIBEIRÃO PRETO            2
# SOROCABA                  2
# UBERABA                   2
# BAURU                     2
# AREALVA                   2
# BOITUVA                   1
# BOCAINA                   1
# BOM JESUS DO AMPARO       1
# BOM JESUS DO GALHO        1
# BEBEDOURO                 1
# BRAGANÇA PAULISTA         1
# BROTAS                    1
# CAJOBI                    1
# ARRAIAL DO CABO           1
# CAMANDUCAIA               1
# TIMÓTEO                   1
# ARAÇATUBA                 1
# CASIMIRO DE ABREU         1
# SANTOS                    1
# COROMANDEL                1
# OLÍMPIA                   1
# RESENDE                   1
# POUSO ALEGRE              1
# PIRASSUNUNGA              1
# PIRACICABA                1
# PIACATU                   1
# PENÁPOLIS                 1
# PARÁ DE MINAS             1
# NOVO HORIZONTE            1
# COSMÓPOLIS                1
# MANGARATIBA               1
# LINHARES                  1
# SÃO BERNARDO DO CAMPO     1
# ITÁPOLIS                  1
# IPERÓ                     1
# SERRA NEGRA               1
# DIAMANTINA                1
# AMERICANA                 1
# dtype: int64

# %%
filtro = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'

dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 25

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# SÃO PAULO                41
# RIO DE JANEIRO           25
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RESENDE                   8
# JUNDIAÍ                   7
# NOVO HORIZONTE            3
# IPERÓ                     3
# TIMÓTEO                   3
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# COSMÓPOLIS                0
# CONFINS                   0
# DIAMANTINA                0
# CASIMIRO DE ABREU         0
# CAMPOS DOS GOYTACAZES     0
# CAMPINAS                  0
# COROMANDEL                0
# VITÓRIA                   0
# CAJOBI                    0
# BROTAS                    0
# GUARULHOS                 0
# BOM JESUS DO AMPARO       0
# BOCAINA                   0
# BEBEDOURO                 0
# BAURU                     0
# ARRAIAL DO CABO           0
# AREALVA                   0
# ARAÇATUBA                 0
# ARARAQUARA                0
# DIVINÓPOLIS               0
# JUIZ DE FORA              0
# IPATINGA                  0
# ITÁPOLIS                  0
# UBERABA                   0
# SÃO JOSÉ DOS CAMPOS       0
# SÃO JOSÉ DO RIO PRETO     0
# SOROCABA                  0
# SERRA NEGRA               0
# SANTOS                    0
# RIBEIRÃO PRETO            0
# POÇOS DE CALDAS           0
# POUSO ALEGRE              0
# PIRASSUNUNGA              0
# PIRACICABA                0
# PIACATU                   0
# PENÁPOLIS                 0
# PARÁ DE MINAS             0
# OLÍMPIA                   0
# MONTES CLAROS             0
# MARÍLIA                   0
# MANGARATIBA               0
# MACAÉ                     0
# LINHARES                  0
# UBERLÂNDIA                0
# AMERICANA                 0
# Name: total_recomendacoes, dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_aerodromo
# NaN     45
# SBMT    27
# SBRJ    19
# SBBP     9
# SBJD     7
# SBGL     3
# SBJR     3
# SDOI     1
# SBPR     1
# SBAQ     0
# SBKP     0
# SBMK     0
# SBME     0
# SBIP     0
# SBBH     0
# SBML     0
# SBCF     0
# SBBU     0
# SBGR     0
# SBPC     0
# SNXT     0
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SBAE     0
# Name: total_recomendacoes, dtype: int64

# %%
filtro = dfsudeste2010.total_recomendacoes > 0

dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# SÃO PAULO                41
# RIO DE JANEIRO           25
# CAMANDUCAIA               9
# BRAGANÇA PAULISTA         9
# RESENDE                   8
# JUNDIAÍ                   7
# TIMÓTEO                   3
# NOVO HORIZONTE            3
# IPERÓ                     3
# SÃO BERNARDO DO CAMPO     2
# BELO HORIZONTE            2
# ITANHAÉM                  1
# BOM JESUS DO GALHO        1
# BOITUVA                   1
# Name: total_recomendacoes, dtype: int64

# %%
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade      ocorrencia_dia
# RIO DE JANEIRO         8                 19
# SÃO PAULO              2                 14
#                        12                11
# BRAGANÇA PAULISTA      11                 9
# CAMANDUCAIA            7                  9
# SÃO PAULO              1                  8
# RESENDE                4                  8
# SÃO PAULO              11                 6
# JUNDIAÍ                5                  5
# TIMÓTEO                2                  3
# IPERÓ                  1                  3
# NOVO HORIZONTE         7                  3
# RIO DE JANEIRO         4                  3
#                        7                  3
# JUNDIAÍ                6                  2
# SÃO BERNARDO DO CAMPO  1                  2
# SÃO PAULO              6                  2
# ITANHAÉM               9                  1
# BOM JESUS DO GALHO     12                 1
# BOITUVA                7                  1
# BELO HORIZONTE         3                  1
#                        2                  1
# Name: total_recomendacoes, dtype: int64
